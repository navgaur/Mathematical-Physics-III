# %% [markdown]
# ***
#
# # **Fourier Series**

# %% [markdown]
# ## Square wave

# %%
import numpy as np
import matplotlib.pyplot as plt 

from scipy.signal import square 
from scipy.integrate import quad 
from math import * 

x=np.arange(-np.pi,np.pi,0.01)  

y=square(x)    

fc=lambda x:square(x)*cos(i*x) 

fs=lambda x:square(x)*sin(i*x)

An=[] 
Bn=[] 

n=30
i=0
a0=quad(fc,-np.pi,np.pi)[0]*(1/np.pi)
sum=a0/2

for i in range(n):
    an=quad(fc,-np.pi,np.pi)[0]*(1/np.pi) 
    An.append(an) 
    bn=quad(fs,-np.pi,np.pi)[0]*(1/np.pi) 
    Bn.append(bn) 

for i in range(n):
    sum= sum + An[i]*np.cos(i*x) + Bn[i]*np.sin(i*x) sawtooth(2*np.pi*freq*t,width=0.5

plt.plot(x,sum,'r--') 

plt.plot(x,y,'b')
plt.show()

# %% [markdown]
# ## Triangle wave

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt 

from scipy.signal import square 
from scipy.integrate import quad 
from math import * 

x = np.arange(0, 101)

def tri(x):
    res = x % 50
    if res < 25:
        return res
    else:
        return 50 - res

plt.plot(x, list(map(tri, x)))

# %% [markdown]
# ## Sawtooth wave

# %%
import numpy as np
from scipy.signal import sawtooth
import matplotlib.pyplot as plt 

from scipy.integrate import quad 

x = np.linspace(0, 2*np.pi, 100)

def sawt(x):
    return sawtooth(x,width=0.5)

y = sawt(x) 

fc=lambda x:sawt(x)*cos(i*x) 
fs=lambda x:sawt(x)*sin(i*x)

An=[] 
Bn=[] 

n=8
i=0
a0=quad(fc,-np.pi,np.pi)[0]*(1/np.pi)
sum=a0/2

for i in range(n):
    an=quad(fc,-np.pi,np.pi)[0]*(1/np.pi) 
    An.append(an) 
    bn=quad(fs,-np.pi,np.pi)[0]*(1/np.pi) 
    Bn.append(bn) 

for i in range(n):
    sum= sum + An[i]*np.cos(i*x) + Bn[i]*np.sin(i*x) 

plt.plot(x,sum,'r--') 

plt.plot(x,y,'b')
plt.show()

# %% [markdown]
# ## Half wave rectifier
# ### (User defined function)

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.integrate import quad

from math import * 

def ff(t):
    if (t < 0): 
        result = 0
    else:
        result = abs(np.sin(t))  
    return result 

period = 2*np.pi 

def fcos(x):
    return ff(x)*cos(i*x) 

def fsin(x):
    return ff(x)*sin(i*x) 

#n=10
n=int(input('Give number of terms: ')) 
steps=int(input('Give step size in x: ')) 

i=0
a0=quad(fcos,-np.pi,np.pi)[0]/(2*np.pi) 

an,bn=[],[] 
for i in range(1,n):
    a=quad(fcos,-np.pi,np.pi)[0]/(np.pi)
    b=quad(fsin,-np.pi,np.pi)[0]/(np.pi)
    an.append(a)
    bn.append(b) 

xx=np.linspace(-np.pi,np.pi,steps) 

y_recon=[] 
for x in xx: 
    sum=a0
    for i in range(1,n):
        sum = sum + an[i-1]*cos(i*x) + bn[i-1]*sin(i*x) 
    y_recon.append(sum) 

y=[] 
for i in xx:
    y.append(ff(i))  

plt.plot(xx,y,'b',label='Signal')
plt.plot(xx,y_recon,'r--',label='Reconst')
plt.xlabel('x') 
plt.ylabel('y') 

plt.legend() 

plt.show()
# Out:
# Give number of terms:  4
# Give step size in x:  100

# %% [markdown]
# ## Triangle wave
# ### (User defined function)

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.integrate import quad

from math import * 

def ff(t):
    if t >=0 and t <= period/4:
        tmp = t/(np.pi/2) 
    elif t > period/4 :
        tmp = 2 - t/(np.pi/2)
    elif t <0 and t >= -period/4:
        tmp =  t/(np.pi/2)
    elif t < -period/4:
        tmp = 2 - t/(np.pi/2)
    result = tmp 
    return result 


period = 2*np.pi 

xx=np.linspace(-np.pi,np.pi,steps) 

y=[] 
for i in xx:
    y.append(ff(i))  

plt.plot(xx,y,'b',label='Signal')
plt.xlabel('x') 
plt.ylabel('y') 

plt.legend() 

plt.show()
